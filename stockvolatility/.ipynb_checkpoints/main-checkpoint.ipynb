# %% [markdown]
# ### STOCK VOLATILITY PREDICTION USING GARCH

# %%
import pandas as pd 
import numpy as np 
import requests
import sqlite3

# %% [markdown]
# ##### Accessing APIs Through a URL

# %% [markdown]
# I'll extract stock market information from the [AlphaVantage](https://alphavantage.co/) API. To get a sense of how an API works, consider the URL below. Take a moment to read the text of the link itself, then click on it and examine the data that appears in your browser. What's the format of the data? What data is included? How is it organized?

# %% [markdown]
# ##### Demo API

# %%
url = ("https://www.alphavantage.co/query?"
       "function=TIME_SERIES_DAILY&"
       "symbol=IBM&"
       "apikey=demo")

print("url type:", type(url))
url
# Out:
# url type: <class 'str'>
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo'

# %% [markdown]
# Now that we have a sense of the components of URL that gets information from AlphaVantage, let's create our own for a different stock.

# %%
url = ("https://www.alphavantage.co/query?"
       "function=TIME_SERIES_DAILY&"
       "symbol=AMBUJACEM.BSE&"
       "apikey=demo")

print("url type:", type(url))
url
# Out:
# url type: <class 'str'>
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AMBUJACEM.BSE&apikey=demo'

# %% [markdown]
# Now that we've stored our API key, we need to import it into our code base. This is commonly done by creating a `config` module.

# %%
# Assuming this is your main script

from config import settings  # Assuming you've renamed config.py to your actual module name

# Access the settings
print(f"Alpha Vantage API Key: {settings.alpha_vantage_api_key}")
print(f"Database Name: {settings.db_name}")
print(f"Model Directory: {settings.model_directory}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Assuming this is your main script
# ----> 3 from config import settings  # Assuming you've renamed config.py to your actual module name
#       5 # Access the settings
#       6 print(f"Alpha Vantage API Key: {settings.alpha_vantage_api_key}")
#
# File ~/StockVolatilityPrediction/stockvolatility/config.py:6
#       1 """This module extracts information from the `.env` file so that
#       2 I can use your AlphaVantage API key in other parts of the application.
#       3 """
#       5 import os
# ----> 6 from pydantic_settings import BaseSettings
#       8 def return_full_path(filename: str = ".env") -> str:
#       9     absolute_path = os.path.abspath(__file__)
#
# ModuleNotFoundError: No module named 'pydantic_settings'

# %%
# dir(settings)

# %% [markdown]
# Now lets create a URL for "AMBUJACEM.BSE". This time, use the base URL `"https://learn-api.wqu.edu/1/data-services/alpha-vantage/query?"` and incorporate your API key.

# %%
url = ("https://www.alphavantage.co/query?"
       "function=TIME_SERIES_DAILY&"
       "symbol=AMBUJACEM.BSE&"
       f"apikey={settings.alpha_vantage_api_key}"
    )

print("url type:", type(url))
url

# %% [markdown]
# <a id="task-815">Go</a> to the documentation for the [AlphaVantage Time Series Daily API](https://www.alphavantage.co/documentation/#daily). Expand your URL to incorporate all the parameters listed in the documentation. Also, to make your URL more dynamic, create variable names for all the parameters that can be added to the URL.

# %%
from IPython.display import Image, display
import os
ROOT = os.getcwd()

image_path = os.path.join(ROOT, "stock.PNG")

# Display the image
display(Image(filename=image_path))

# %%
# !pip install pydantic_settings
# Out:
# Collecting pydantic_settings
#   Using cached pydantic_settings-2.2.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: pydantic>=2.3.0 in /Users/taofeekolawoye/anaconda3/envs/venv/lib/python3.10/site-packages (from pydantic_settings) (2.5.3)
# Collecting python-dotenv>=0.21.0 (from pydantic_settings)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/taofeekolawoye/anaconda3/envs/venv/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic_settings) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/taofeekolawoye/anaconda3/envs/venv/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic_settings) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/taofeekolawoye/anaconda3/envs/venv/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic_settings) (4.7.1)
# Using cached pydantic_settings-2.2.1-py3-none-any.whl (13 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, pydantic_settings
# Successfully installed pydantic_settings-2.2.1 python-dotenv-1.0.1

# %%
from config import settings

# %% [markdown]
# Now let's get a better view of our Data to be extracted by considering other Parameters

# %%
ticker = "AMBUJACEM.BSE"
output_size = "compact"
data_type = "json"

url = ("https://www.alphavantage.co/query?"
       "function=TIME_SERIES_DAILY&"
       f"symbol={ticker}&"
       f"outputsize={output_size}&"
       f"datatype={data_type}&"
       f"apikey={settings.alpha_vantage_api_key}"
    )

print("url type:", type(url))
url
# Out:
# url type: <class 'str'>
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AMBUJACEM.BSE&outputsize=compact&datatype=json&apikey=INCQJAFFKS1UL381'

# %% [markdown]
# Let's implement the above as a Function that takes in those parameters and return a url link

# %%
def alphavantage_url(ticker : str, output_size : str, data_type : str):
    base_url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&"
    url = (base_url + f"symbol={ticker}&" + 
                f"outputsize={output_size}&" + f"datatype={data_type}&" +
                     f"apikey={settings.alpha_vantage_api_key}")  
    return url

# %%
url = alphavantage_url("AMBUJACEM.BSE", "compact", "json")
url
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AMBUJACEM.BSE&outputsize=compact&datatype=json&apikey=INCQJAFFKS1UL381'

# %% [markdown]
# #### Accessing APIs Through a Request

# %%
response = requests.get(url=url)

# %%
print("response type:", type(response))
# Out:
# response type: <class 'requests.models.Response'>

# %%
# dir(response)

# %%
response.status_code
# Out:
# 200

# %%
# Getting Response Json

response_data = response.json()

print("response_data type:", type(response_data))
# Out:
# response_data type: <class 'dict'>

# %%
# Response Data Key
response_data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
response_data["Time Series (Daily)"]
# Out:
# {'2024-02-20': {'1. open': '585.0000',
#   '2. high': '590.0000',
#   '3. low': '579.7000',
#   '4. close': '588.8000',
#   '5. volume': '70585'},
#  '2024-02-19': {'1. open': '586.6500',
#   '2. high': '593.8000',
#   '3. low': '581.7000',
#   '4. close': '584.8000',
#   '5. volume': '204358'},
#  '2024-02-16': {'1. open': '572.5000',
#   '2. high': '590.4500',
#   '3. low': '572.5000',
#   '4. close': '585.2500',
#   '5. volume': '197780'},
#  '2024-02-15': {'1. open': '573.6500',
#   '2. high': '574.8000',
#   '3. low': '568.7500',
#   '4. close': '571.8000',
#   '5. volume': '46967'},
#  '2024-02-14': {'1. open': '560.8500',
#   '2. high': '573.1000',
#   '3. low': '559.7000',
#   '4. close': '570.8500',
#   '5. volume': '101565'},
#  '2024-02-13': {'1. open': '562.7000',
#   '2. high': '570.0000',
#   '3. low': '552.3500',
#   '4. close': '568.3500',
#   '5. volume': '107815'},
#  '2024-02-12': {'1. open': '582.0000',
#   '2. high': '587.0000',
#   '3. low': '561.0000',
#   '4. close': '564.1500',
#   '5. volume': '296376'},
#  '2024-02-09': {'1. open': '563.9500',
#   '2. high': '582.2000',
#   '3. low': '552.5500',
#   '4. close': '576.6000',
#   '5. volume': '160519'},
#  '2024-02-08': {'1. open': '567.7000',
#   '2. high': '571.0000',
#   '3. low': '560.0000',
#   '4. close': '563.0000',
#   '5. volume': '56438'},
#  '2024-02-07': {'1. open': '570.0000',
#   '2. high': '575.3000',
#   '3. low': '564.3000',
#   '4. close': '567.6500',
#   '5. volume': '66087'},
#  '2024-02-06': {'1. open': '555.3000',
#   '2. high': '567.5500',
#   '3. low': '550.0000',
#   '4. close': '566.5000',
#   '5. volume': '107559'},
#  '2024-02-05': {'1. open': '557.5000',
#   '2. high': '563.0000',
#   '3. low': '551.0000',
#   '4. close': '553.8500',
#   '5. volume': '256270'},
#  '2024-02-02': {'1. open': '571.4000',
#   '2. high': '572.4500',
#   '3. low': '554.9500',
#   '4. close': '557.3000',
#   '5. volume': '223662'},
#  '2024-02-01': {'1. open': '568.7500',
#   '2. high': '569.8000',
#   '3. low': '554.2500',
#   '4. close': '565.1000',
#   '5. volume': '328061'},
#  '2024-01-31': {'1. open': '572.1500',
#   '2. high': '586.0000',
#   '3. low': '547.4500',
#   '4. close': '560.3500',
#   '5. volume': '412289'},
#  '2024-01-30': {'1. open': '576.6500',
#   '2. high': '583.7500',
#   '3. low': '568.0000',
#   '4. close': '570.5000',
#   '5. volume': '223060'},
#  '2024-01-29': {'1. open': '570.1500',
#   '2. high': '578.5000',
#   '3. low': '562.4000',
#   '4. close': '573.7500',
#   '5. volume': '591660'},
#  '2024-01-25': {'1. open': '529.2500',
#   '2. high': '565.8000',
#   '3. low': '527.4500',
#   '4. close': '560.5000',
#   '5. volume': '1383745'},
#  '2024-01-24': {'1. open': '525.0000',
#   '2. high': '530.3500',
#   '3. low': '515.0000',
#   '4. close': '527.6000',
#   '5. volume': '154607'},
#  '2024-01-23': {'1. open': '546.8500',
#   '2. high': '546.8500',
#   '3. low': '517.4500',
#   '4. close': '525.4500',
#   '5. volume': '109083'},
#  '2024-01-22': {'1. open': '537.1500',
#   '2. high': '537.1500',
#   '3. low': '537.1500',
#   '4. close': '537.1500',
#   '5. volume': '0'},
#  '2024-01-20': {'1. open': '538.7500',
#   '2. high': '545.8000',
#   '3. low': '531.9500',
#   '4. close': '540.7000',
#   '5. volume': '181181'},
#  '2024-01-19': {'1. open': '527.5500',
#   '2. high': '538.0000',
#   '3. low': '525.4000',
#   '4. close': '537.1500',
#   '5. volume': '83485'},
#  '2024-01-18': {'1. open': '520.8000',
#   '2. high': '526.9000',
#   '3. low': '509.5500',
#   '4. close': '523.9500',
#   '5. volume': '77791'},
#  '2024-01-17': {'1. open': '525.1500',
#   '2. high': '539.3000',
#   '3. low': '518.0500',
#   '4. close': '520.5000',
#   '5. volume': '216483'},
#  '2024-01-16': {'1. open': '531.7000',
#   '2. high': '534.9000',
#   '3. low': '524.6500',
#   '4. close': '528.8000',
#   '5. volume': '87314'},
#  '2024-01-15': {'1. open': '533.2500',
#   '2. high': '536.4500',
#   '3. low': '526.7000',
#   '4. close': '531.5500',
#   '5. volume': '233251'},
#  '2024-01-12': {'1. open': '540.4000',
#   '2. high': '544.8000',
#   '3. low': '531.4500',
#   '4. close': '532.4000',
#   '5. volume': '84821'},
#  '2024-01-11': {'1. open': '529.4500',
#   '2. high': '541.2000',
#   '3. low': '525.5000',
#   '4. close': '538.1500',
#   '5. volume': '123872'},
#  '2024-01-10': {'1. open': '526.1500',
#   '2. high': '528.3500',
#   '3. low': '518.3000',
#   '4. close': '526.0500',
#   '5. volume': '111564'},
#  '2024-01-09': {'1. open': '535.2500',
#   '2. high': '538.8500',
#   '3. low': '523.4500',
#   '4. close': '525.2500',
#   '5. volume': '142298'},
#  '2024-01-08': {'1. open': '543.7000',
#   '2. high': '544.2000',
#   '3. low': '526.7000',
#   '4. close': '530.2000',
#   '5. volume': '217570'},
#  '2024-01-05': {'1. open': '550.0000',
#   '2. high': '557.7500',
#   '3. low': '538.4000',
#   '4. close': '542.2500',
#   '5. volume': '172194'},
#  '2024-01-04': {'1. open': '536.6500',
#   '2. high': '554.2500',
#   '3. low': '536.6500',
#   '4. close': '549.3500',
#   '5. volume': '464411'},
#  '2024-01-03': {'1. open': '538.2000',
#   '2. high': '549.0000',
#   '3. low': '527.6000',
#   '4. close': '536.4000',
#   '5. volume': '471931'},
#  '2024-01-02': {'1. open': '536.0500',
#   '2. high': '537.0000',
#   '3. low': '518.2000',
#   '4. close': '530.6000',
#   '5. volume': '280599'},
#  '2024-01-01': {'1. open': '520.5500',
#   '2. high': '539.5500',
#   '3. low': '519.9500',
#   '4. close': '534.7000',
#   '5. volume': '391506'},
#  '2023-12-29': {'1. open': '511.5500',
#   '2. high': '522.3000',
#   '3. low': '511.3000',
#   '4. close': '520.9500',
#   '5. volume': '179989'},
#  '2023-12-28': {'1. open': '517.3500',
#   '2. high': '519.7500',
#   '3. low': '512.2000',
#   '4. close': '514.2500',
#   '5. volume': '69935'},
#  '2023-12-27': {'1. open': '520.0500',
#   '2. high': '523.0000',
#   '3. low': '513.2500',
#   '4. close': '516.4000',
#   '5. volume': '218846'},
#  '2023-12-26': {'1. open': '503.8000',
#   '2. high': '508.5000',
#   '3. low': '502.9500',
#   '4. close': '505.1500',
#   '5. volume': '114257'},
#  '2023-12-22': {'1. open': '505.6500',
#   '2. high': '509.4500',
#   '3. low': '498.2000',
#   '4. close': '503.8000',
#   '5. volume': '85760'},
#  '2023-12-21': {'1. open': '477.3000',
#   '2. high': '505.9500',
#   '3. low': '477.3000',
#   '4. close': '503.8000',
#   '5. volume': '584091'},
#  '2023-12-20': {'1. open': '523.2500',
#   '2. high': '526.0000',
#   '3. low': '486.4500',
#   '4. close': '490.5500',
#   '5. volume': '216525'},
#  '2023-12-19': {'1. open': '529.8500',
#   '2. high': '529.9000',
#   '3. low': '516.7500',
#   '4. close': '522.3000',
#   '5. volume': '74154'},
#  '2023-12-18': {'1. open': '529.6000',
#   '2. high': '532.5500',
#   '3. low': '524.3000',
#   '4. close': '525.4500',
#   '5. volume': '168807'},
#  '2023-12-15': {'1. open': '523.1000',
#   '2. high': '529.6000',
#   '3. low': '514.6500',
#   '4. close': '522.3500',
#   '5. volume': '316907'},
#  '2023-12-14': {'1. open': '514.0000',
#   '2. high': '523.3500',
#   '3. low': '511.7500',
#   '4. close': '520.3500',
#   '5. volume': '163569'},
#  '2023-12-13': {'1. open': '503.2000',
#   '2. high': '513.3500',
#   '3. low': '502.4000',
#   '4. close': '509.0000',
#   '5. volume': '116481'},
#  '2023-12-12': {'1. open': '505.0500',
#   '2. high': '510.2000',
#   '3. low': '497.5000',
#   '4. close': '501.3000',
#   '5. volume': '206019'},
#  '2023-12-11': {'1. open': '497.4000',
#   '2. high': '506.7000',
#   '3. low': '489.3500',
#   '4. close': '504.2000',
#   '5. volume': '229758'},
#  '2023-12-08': {'1. open': '505.5000',
#   '2. high': '509.8500',
#   '3. low': '482.3500',
#   '4. close': '494.3500',
#   '5. volume': '369578'},
#  '2023-12-07': {'1. open': '505.9500',
#   '2. high': '508.4500',
#   '3. low': '496.2500',
#   '4. close': '505.1000',
#   '5. volume': '332573'},
#  '2023-12-06': {'1. open': '515.8500',
#   '2. high': '523.7000',
#   '3. low': '499.4500',
#   '4. close': '501.1500',
#   '5. volume': '529930'},
#  '2023-12-05': {'1. open': '475.0000',
#   '2. high': '513.4000',
#   '3. low': '474.6000',
#   '4. close': '508.7000',
#   '5. volume': '932400'},
#  '2023-12-04': {'1. open': '457.1500',
#   '2. high': '475.8000',
#   '3. low': '453.1000',
#   '4. close': '474.4500',
#   '5. volume': '1259661'},
#  '2023-12-01': {'1. open': '443.8000',
#   '2. high': '443.8000',
#   '3. low': '438.0500',
#   '4. close': '442.1000',
#   '5. volume': '79760'},
#  '2023-11-30': {'1. open': '437.5500',
#   '2. high': '442.9500',
#   '3. low': '430.8000',
#   '4. close': '438.8000',
#   '5. volume': '135172'},
#  '2023-11-29': {'1. open': '434.0500',
#   '2. high': '437.1000',
#   '3. low': '428.1500',
#   '4. close': '435.5500',
#   '5. volume': '354642'},
#  '2023-11-28': {'1. open': '415.6500',
#   '2. high': '435.4000',
#   '3. low': '415.6500',
#   '4. close': '431.2000',
#   '5. volume': '255414'},
#  '2023-11-24': {'1. open': '414.8500',
#   '2. high': '415.5500',
#   '3. low': '411.3500',
#   '4. close': '413.7500',
#   '5. volume': '90573'},
#  '2023-11-23': {'1. open': '414.4000',
#   '2. high': '416.7500',
#   '3. low': '408.6000',
#   '4. close': '415.5000',
#   '5. volume': '93005'},
#  '2023-11-22': {'1. open': '419.1500',
#   '2. high': '420.8500',
#   '3. low': '413.1500',
#   '4. close': '414.3000',
#   '5. volume': '38283'},
#  '2023-11-21': {'1. open': '421.5500',
#   '2. high': '424.2000',
#   '3. low': '419.0000',
#   '4. close': '420.0500',
#   '5. volume': '73550'},
#  '2023-11-20': {'1. open': '420.9000',
#   '2. high': '424.1000',
#   '3. low': '418.2500',
#   '4. close': '421.5000',
#   '5. volume': '707595'},
#  '2023-11-17': {'1. open': '421.1000',
#   '2. high': '427.8000',
#   '3. low': '418.9000',
#   '4. close': '420.9000',
#   '5. volume': '92228'},
#  '2023-11-16': {'1. open': '419.1000',
#   '2. high': '420.2500',
#   '3. low': '417.0500',
#   '4. close': '419.7500',
#   '5. volume': '50274'},
#  '2023-11-15': {'1. open': '420.1000',
#   '2. high': '423.4500',
#   '3. low': '417.7000',
#   '4. close': '418.1000',
#   '5. volume': '77842'},
#  '2023-11-13': {'1. open': '421.5000',
#   '2. high': '422.2000',
#   '3. low': '418.3500',
#   '4. close': '419.3500',
#   '5. volume': '43388'},
#  '2023-11-10': {'1. open': '418.3000',
#   '2. high': '419.9000',
#   '3. low': '415.7000',
#   '4. close': '417.9500',
#   '5. volume': '48415'},
#  '2023-11-09': {'1. open': '424.9500',
#   '2. high': '424.9500',
#   '3. low': '416.1000',
#   '4. close': '418.3500',
#   '5. volume': '39214'},
#  '2023-11-08': {'1. open': '419.3500',
#   '2. high': '426.0000',
#   '3. low': '419.2500',
#   '4. close': '420.9500',
#   '5. volume': '68434'},
#  '2023-11-07': {'1. open': '421.4000',
#   '2. high': '423.0000',
#   '3. low': '418.1000',
#   '4. close': '419.3000',
#   '5. volume': '54946'},
#  '2023-11-06': {'1. open': '422.0000',
#   '2. high': '425.0000',
#   '3. low': '420.0500',
#   '4. close': '421.2500',
#   '5. volume': '34068'},
#  '2023-11-03': {'1. open': '421.5500',
#   '2. high': '423.0000',
#   '3. low': '417.3000',
#   '4. close': '420.8500',
#   '5. volume': '50722'},
#  '2023-11-02': {'1. open': '410.0000',
#   '2. high': '423.1500',
#   '3. low': '410.0000',
#   '4. close': '419.3000',
#   '5. volume': '205833'},
#  '2023-11-01': {'1. open': '425.0500',
#   '2. high': '425.6000',
#   '3. low': '404.0000',
#   '4. close': '406.7500',
#   '5. volume': '237965'},
#  '2023-10-31': {'1. open': '424.0000',
#   '2. high': '427.0000',
#   '3. low': '421.0000',
#   '4. close': '424.5000',
#   '5. volume': '39594'},
#  '2023-10-30': {'1. open': '420.0000',
#   '2. high': '423.8000',
#   '3. low': '416.4500',
#   '4. close': '421.8500',
#   '5. volume': '55409'},
#  '2023-10-27': {'1. open': '416.4000',
#   '2. high': '423.9500',
#   '3. low': '415.5000',
#   '4. close': '417.5000',
#   '5. volume': '45753'},
#  '2023-10-26': {'1. open': '415.0000',
#   '2. high': '422.0000',
#   '3. low': '408.0000',
#   '4. close': '415.7000',
#   '5. volume': '47088'},
#  '2023-10-25': {'1. open': '418.7500',
#   '2. high': '422.7000',
#   '3. low': '414.0000',
#   '4. close': '417.7000',
#   '5. volume': '50400'},
#  '2023-10-23': {'1. open': '430.9000',
#   '2. high': '432.5500',
#   '3. low': '411.2500',
#   '4. close': '415.7500',
#   '5. volume': '135899'},
#  '2023-10-20': {'1. open': '437.3000',
#   '2. high': '439.3000',
#   '3. low': '428.4000',
#   '4. close': '430.8500',
#   '5. volume': '39520'},
#  '2023-10-19': {'1. open': '433.5000',
#   '2. high': '440.0000',
#   '3. low': '430.0000',
#   '4. close': '437.3000',
#   '5. volume': '80559'},
#  '2023-10-18': {'1. open': '441.2000',
#   '2. high': '444.1500',
#   '3. low': '431.5000',
#   '4. close': '433.0500',
#   '5. volume': '35889'},
#  '2023-10-17': {'1. open': '442.8000',
#   '2. high': '444.3500',
#   '3. low': '440.0500',
#   '4. close': '442.1500',
#   '5. volume': '38178'},
#  '2023-10-16': {'1. open': '438.4500',
#   '2. high': '444.9000',
#   '3. low': '438.4500',
#   '4. close': '443.1500',
#   '5. volume': '105784'},
#  '2023-10-13': {'1. open': '443.0500',
#   '2. high': '446.0000',
#   '3. low': '438.7500',
#   '4. close': '439.9500',
#   '5. volume': '42045'},
#  '2023-10-12': {'1. open': '447.0500',
#   '2. high': '450.4000',
#   '3. low': '443.9000',
#   '4. close': '445.5500',
#   '5. volume': '123507'},
#  '2023-10-11': {'1. open': '438.2000',
#   '2. high': '447.0000',
#   '3. low': '438.1500',
#   '4. close': '445.5000',
#   '5. volume': '80948'},
#  '2023-10-10': {'1. open': '428.4500',
#   '2. high': '438.8000',
#   '3. low': '428.4500',
#   '4. close': '437.0500',
#   '5. volume': '59294'},
#  '2023-10-09': {'1. open': '430.0000',
#   '2. high': '437.3500',
#   '3. low': '427.3000',
#   '4. close': '430.0500',
#   '5. volume': '56311'},
#  '2023-10-06': {'1. open': '433.1000',
#   '2. high': '436.8500',
#   '3. low': '431.9000',
#   '4. close': '435.3000',
#   '5. volume': '37174'},
#  '2023-10-05': {'1. open': '430.7500',
#   '2. high': '434.7000',
#   '3. low': '428.8000',
#   '4. close': '432.8000',
#   '5. volume': '71722'},
#  '2023-10-04': {'1. open': '430.0000',
#   '2. high': '434.2000',
#   '3. low': '424.4500',
#   '4. close': '429.7000',
#   '5. volume': '125181'},
#  '2023-10-03': {'1. open': '424.8000',
#   '2. high': '434.2000',
#   '3. low': '422.7000',
#   '4. close': '432.3500',
#   '5. volume': '149141'},
#  '2023-09-29': {'1. open': '422.4000',
#   '2. high': '428.6500',
#   '3. low': '420.5500',
#   '4. close': '425.0000',
#   '5. volume': '87484'},
#  '2023-09-28': {'1. open': '430.5000',
#   '2. high': '431.4500',
#   '3. low': '418.5000',
#   '4. close': '420.1000',
#   '5. volume': '96569'},
#  '2023-09-27': {'1. open': '427.4000',
#   '2. high': '431.3500',
#   '3. low': '426.0000',
#   '4. close': '430.5000',
#   '5. volume': '41243'}}

# %%
stock_data = response_data["Time Series (Daily)"]

# %% [markdown]
# Read the data from `stock_data` into a DataFrame

# %%
df_ambuja = pd.DataFrame.from_dict(stock_data, orient="index", dtype=float)

# %%
df_ambuja
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2024-02-20   585.00   590.00  579.70    588.80    70585.0
# 2024-02-19   586.65   593.80  581.70    584.80   204358.0
# 2024-02-16   572.50   590.45  572.50    585.25   197780.0
# 2024-02-15   573.65   574.80  568.75    571.80    46967.0
# 2024-02-14   560.85   573.10  559.70    570.85   101565.0
# ...             ...      ...     ...       ...        ...
# 2023-10-04   430.00   434.20  424.45    429.70   125181.0
# 2023-10-03   424.80   434.20  422.70    432.35   149141.0
# 2023-09-29   422.40   428.65  420.55    425.00    87484.0
# 2023-09-28   430.50   431.45  418.50    420.10    96569.0
# 2023-09-27   427.40   431.35  426.00    430.50    41243.0
#
# [100 rows x 5 columns]

# %%
print("df_ambuja shape:", df_ambuja.shape)
print()
print(df_ambuja.info())
df_ambuja.head(10)
# Out:
# df_ambuja shape: (100, 5)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 2024-02-20 to 2023-09-27
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    100 non-null    float64
#  1   2. high    100 non-null    float64
#  2   3. low     100 non-null    float64
#  3   4. close   100 non-null    float64
#  4   5. volume  100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.7+ KB
# None
#             1. open  2. high  3. low  4. close  5. volume
# 2024-02-20   585.00   590.00  579.70    588.80    70585.0
# 2024-02-19   586.65   593.80  581.70    584.80   204358.0
# 2024-02-16   572.50   590.45  572.50    585.25   197780.0
# 2024-02-15   573.65   574.80  568.75    571.80    46967.0
# 2024-02-14   560.85   573.10  559.70    570.85   101565.0
# 2024-02-13   562.70   570.00  552.35    568.35   107815.0
# 2024-02-12   582.00   587.00  561.00    564.15   296376.0
# 2024-02-09   563.95   582.20  552.55    576.60   160519.0
# 2024-02-08   567.70   571.00  560.00    563.00    56438.0
# 2024-02-07   570.00   575.30  564.30    567.65    66087.0

# %%
# Converting the Date from string, to Date time index
df_ambuja.index = pd.to_datetime(df_ambuja.index)

# Lets give our index name 
df_ambuja.index.name = "Date"

# %%
df_ambuja.head()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# Date
# 2024-02-20   585.00   590.00  579.70    588.80    70585.0
# 2024-02-19   586.65   593.80  581.70    584.80   204358.0
# 2024-02-16   572.50   590.45  572.50    585.25   197780.0
# 2024-02-15   573.65   574.80  568.75    571.80    46967.0
# 2024-02-14   560.85   573.10  559.70    570.85   101565.0

# %%
df_ambuja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 2024-02-20 to 2023-09-27
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    100 non-null    float64
#  1   2. high    100 non-null    float64
#  2   3. low     100 non-null    float64
#  3   4. close   100 non-null    float64
#  4   5. volume  100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.7 KB

# %%
[col[1] for col in (col for col in df_ambuja.columns.str.split(" "))]
# Out:
# ['open', 'high', 'low', 'close', 'volume']

# %%
[col[3:] for col in df_ambuja.columns]
# Out:
# ['open', 'high', 'low', 'close', 'volume']

# %%
[col.split(" ")[1] for col in df_ambuja.columns]
# Out:
# ['open', 'high', 'low', 'close', 'volume']

# %%
# Name the columns like this excatly the same way by removing the number and . in front of the name
df_ambuja.columns = [col[1] for col in (col for col in df_ambuja.columns.str.split(" "))]

# %%
# Or Renaming the columns for better understanding
df_ambuja.rename(columns={"1. open": "Open Price", "2. high":"Highest Price", 
                    "3. low": "Lowest Price", "4. close": "Closing Price", 
                    "5. volume": "Volume"}, inplace=True)

# %%
df_ambuja.head()
# Out:
#               open    high     low   close    volume
# Date
# 2024-02-20  585.00  590.00  579.70  588.80   70585.0
# 2024-02-19  586.65  593.80  581.70  584.80  204358.0
# 2024-02-16  572.50  590.45  572.50  585.25  197780.0
# 2024-02-15  573.65  574.80  568.75  571.80   46967.0
# 2024-02-14  560.85  573.10  559.70  570.85  101565.0

# %%
df_ambuja.shape
# Out:
# (100, 5)

# %% [markdown]
# <font size="+3"><strong> Test Driven Development</strong></font>

# %% [markdown]
# Now I have two goals. First, I'll take the code I used to access the API and build an `AlphaVantageAPI` class. This will allow me to reuse our code. Second, I'll create a `SQLRepository` class that will help me load our stock data into a SQLite database and then extract it for later use. Additionally, I'll build this code using a technique called **test driven development**, where I'll use `assert` statements to make sure everything is working properly. That way, I'll avoid issues later when I build the application.

# %%
# Instantiate the class from data.py 
from data import AlphaVantageAPI, SQLRepository

av = AlphaVantageAPI()

# %%
# Define Suzlon ticker symbol
ticker = "SUZLON.BSE"

# Use your `av` object to get daily data
df_suzlon = av.get_daily(ticker=ticker)

print("df_suzlon type:", type(df_suzlon))
print("df_suzlon shape:", df_suzlon.shape)
df_suzlon.head()
# Out:
# df_suzlon type: <class 'pandas.core.frame.DataFrame'>
# df_suzlon shape: (4519, 5)
#              open   high    low  close     volume
# Date
# 2024-02-20  46.74  46.89  45.60  45.78  1830324.0
# 2024-02-19  47.45  47.50  46.05  46.13  2391635.0
# 2024-02-16  47.67  47.67  46.20  46.76  3191162.0
# 2024-02-15  46.95  47.70  46.50  47.00  9793535.0
# 2024-02-14  42.50  46.07  42.05  46.07  7044652.0

# %%
df_suzlon.index = pd.to_datetime(df_suzlon.index)

# %%
# Does `get_daily` return a DataFrame?
assert isinstance(df_suzlon, pd.DataFrame)

# Does DataFrame have 5 columns?
assert df_suzlon.shape[1] == 5

# Does DataFrame have a DatetimeIndex?
assert type(df_suzlon.index) == pd.DatetimeIndex
# assert isinstance(df_suzlon.index , pd.DatetimeIndex)

# Is the index name "date"?
assert df_suzlon.index.name == "Date"

# %%
# Does DataFrame have correct column names?
assert df_suzlon.columns.to_list() == ['open', 'high', 'low', 'close', 'volume']
# all(df_suzlon.columns == ['open', 'high', 'low', 'close', 'volume'])

# Are columns correct data type?
assert df_suzlon.columns.dtype == pd.Float64Dtype

# %%
sql_connection = sqlite3.connect(database=settings.db_name, check_same_thread=False)

# %%
class SQLRepository:
    def __init__(self, connection):
        self.connection = connection

    def insert_table(self, table_name, records, if_exists="fail"):
        """Insert DataFrame into SQLite database as table.

        Parameters
        ----------
        table_name : str
        records : pd.DataFrame
        if_exists : str, optional
            How to behave if the table already exists.

            - 'fail': Raise a ValueError.
            - 'replace': Drop the table before inserting new values.
            - 'append': Insert new values to the existing table.

            Default: 'fail'

        Returns
        -------
        dict
            Dictionary has two keys:

            - 'transaction_successful', followed by bool
            - 'records_inserted', followed by int
        """
        n_inserted = records.to_sql(name=table_name, con=self.connection, if_exists=if_exists)
        return {
            "records_inserted": n_inserted,
            "transaction_successful": True
        }

    def read_table(self, table_name, limit=None):
        """Read table from database.

        Parameters
        ----------
        table_name : str
            Name of the table in the SQLite database.
        limit : int, None, optional
            Number of most recent records to retrieve. If `None`, all
            records are retrieved. Default: None.

        Returns
        -------
        pd.DataFrame
            Index is DatetimeIndex "date". Columns are 'open', 'high',
            'low', 'close', and 'volume'. All columns are numeric.
        """
        # Create SQL query (with optional limit)
        if limit:
            query = f"SELECT * FROM '{table_name}' LIMIT {limit}"
        else:
            query = f"SELECT * FROM '{table_name}'"

        # Retrieve data, read into DataFrame
        df = pd.read_sql(sql=query, con=self.connection, parse_dates=["Date"])
        df.set_index("Date", inplace=True)
        # Return DataFrame
        return df

# %%
# Create instance of class
repo = SQLRepository(connection=sql_connection)

# Does `repo` have a "connection" attribute?
assert hasattr(repo, "connection")

# Is the "connection" attribute a SQLite `Connection`?
assert isinstance(repo.connection, sqlite3.Connection)

# %%
response = repo.insert_table(table_name=ticker, records=df_suzlon, if_exists="replace")

# Does your method return a dictionary?
assert isinstance(response, dict)

# Are the keys of that dictionary correct?
assert sorted(list(response.keys())) == ["records_inserted", "transaction_successful"]

# %%
# %load_ext sql

# %%
os.getcwd()
# Out:
# '/Users/taofeekolawoye/StockVolatilityPrediction/stockvolatility'

# %%
# %sql sqlite:////Users/taofeekolawoye/StockVolatilityPrediction/stockvolatility/stocks.sqlite
# Out:
# 'Connected: @/Users/taofeekolawoye/StockVolatilityPrediction/stockvolatility/stocks.sqlite'

# %%
# %%sql
#
# SELECT *
# from "SUZLON.BSE"
# limit 10;
# Out:
#  * sqlite:////Users/taofeekolawoye/StockVolatilityPrediction/stockvolatility/stocks.sqlite
# Done.
# [('2024-02-20 00:00:00', 46.74, 46.89, 45.6, 45.78, 1830324.0),
#  ('2024-02-19 00:00:00', 47.45, 47.5, 46.05, 46.13, 2391635.0),
#  ('2024-02-16 00:00:00', 47.67, 47.67, 46.2, 46.76, 3191162.0),
#  ('2024-02-15 00:00:00', 46.95, 47.7, 46.5, 47.0, 9793535.0),
#  ('2024-02-14 00:00:00', 42.5, 46.07, 42.05, 46.07, 7044652.0),
#  ('2024-02-13 00:00:00', 43.55, 44.69, 42.77, 43.88, 24741190.0),
#  ('2024-02-12 00:00:00', 47.94, 48.25, 45.02, 45.02, 13832000.0),
#  ('2024-02-09 00:00:00', 49.4, 49.4, 46.88, 47.38, 9582765.0),
#  ('2024-02-08 00:00:00', 49.5, 49.74, 48.51, 49.34, 10803370.0),
#  ('2024-02-07 00:00:00', 48.31, 49.93, 48.2, 49.26, 15900350.0)]

# %%
df_suzlon.shape
# Out:
# (4519, 5)

# %%
# Assign `read_table` output to `df_suzlon`
df_suzlon = repo.read_table(table_name="SUZLON.BSE", limit=2500)  # Enclose table name in double quotes

# Is `df_suzlon` a DataFrame?
assert isinstance(df_suzlon, pd.DataFrame)

# Does it have a `DatetimeIndex`?
assert isinstance(df_suzlon.index, pd.DatetimeIndex)

# Is the index named "date"?
assert df_suzlon.index.name == "Date"

print(df_suzlon.shape)

# Does it have 2,500 rows and 5 columns?
assert df_suzlon.shape == (2500, 5)

# Are the column names correct?
assert df_suzlon.columns.to_list() == ['open', 'high', 'low', 'close', 'volume']

# Are the column data types correct?
assert all(df_suzlon.dtypes == float)

# Print `df_suzlon` info
print("df_suzlon shape:", df_suzlon.shape)
print()
print(df_suzlon.info())
df_suzlon.head()
# Out:
# (2500, 5)
# df_suzlon shape: (2500, 5)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2500 entries, 2024-02-20 to 2013-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    2500 non-null   float64
#  1   high    2500 non-null   float64
#  2   low     2500 non-null   float64
#  3   close   2500 non-null   float64
#  4   volume  2500 non-null   float64
# dtypes: float64(5)
# memory usage: 117.2 KB
# None
#              open   high    low  close     volume
# Date
# 2024-02-20  46.74  46.89  45.60  45.78  1830324.0
# 2024-02-19  47.45  47.50  46.05  46.13  2391635.0
# 2024-02-16  47.67  47.67  46.20  46.76  3191162.0
# 2024-02-15  46.95  47.70  46.50  47.00  9793535.0
# 2024-02-14  42.50  46.07  42.05  46.07  7044652.0

# %%
# Define Apple ticker symbol
ticker = "AAPL"

# Use your `av` object to get daily data
df_apple = av.get_daily(ticker=ticker)

print("df_apple type:", type(df_apple))
print("df_apple shape:", df_apple.shape)
df_apple.head()
# Out:
# df_apple type: <class 'pandas.core.frame.DataFrame'>
# df_apple shape: (6114, 5)
#               open    high       low   close      volume
# Date
# 2024-02-20  181.79  182.43  180.0000  181.56  53665553.0
# 2024-02-16  183.42  184.85  181.6650  182.31  49752465.0
# 2024-02-15  183.55  184.49  181.3500  183.86  65434496.0
# 2024-02-14  185.32  185.53  182.4400  184.15  54630517.0
# 2024-02-13  185.77  186.21  183.5128  185.04  56529529.0

# %%
response = repo.insert_table(table_name="APPL", records=df_apple, if_exists="replace")

# Does your method return a dictionary?
assert isinstance(response, dict)

# Are the keys of that dictionary correct?
assert sorted(list(response.keys())) == ["records_inserted", "transaction_successful"]

# %%
ticker = "APPL"
df_apple = repo.read_table(table_name=ticker, limit=None)

print("df_apple type:", type(df_apple))
print("df_apple shape:", df_apple.shape)
df_apple.head()
# Out:
# df_apple type: <class 'pandas.core.frame.DataFrame'>
# df_apple shape: (6114, 5)
#               open    high       low   close      volume
# Date
# 2024-02-20  181.79  182.43  180.0000  181.56  53665553.0
# 2024-02-16  183.42  184.85  181.6650  182.31  49752465.0
# 2024-02-15  183.55  184.49  181.3500  183.86  65434496.0
# 2024-02-14  185.32  185.53  182.4400  184.15  54630517.0
# 2024-02-13  185.77  186.21  183.5128  185.04  56529529.0

# %%
# Define Apple ticker symbol
ticker = "AMBUJACEM.BSE"

# Use your `av` object to get daily data
df_ambuja = av.get_daily(ticker=ticker)

print("df_ambuja type:", type(df_ambuja))
print("df_ambuja shape:", df_ambuja.shape)
df_ambuja.head()
# Out:
# df_ambuja type: <class 'pandas.core.frame.DataFrame'>
# df_ambuja shape: (4716, 5)
#               open    high     low   close    volume
# Date
# 2024-02-20  585.00  590.00  579.70  588.80   70585.0
# 2024-02-19  586.65  593.80  581.70  584.80  204358.0
# 2024-02-16  572.50  590.45  572.50  585.25  197780.0
# 2024-02-15  573.65  574.80  568.75  571.80   46967.0
# 2024-02-14  560.85  573.10  559.70  570.85  101565.0

# %%
response = repo.insert_table(table_name="AMBUJACEM.BSE", records=df_ambuja, if_exists="replace")

# Does your method return a dictionary?
assert isinstance(response, dict)

# Are the keys of that dictionary correct?
assert sorted(list(response.keys())) == ["records_inserted", "transaction_successful"]

# %%
ticker = "AMBUJACEM.BSE"
df_ambuja = repo.read_table(table_name=ticker, limit=None)

print("df_ambuja type:", type(df_ambuja))
print("df_ambuja shape:", df_ambuja.shape)
df_ambuja.head()
# Out:
# df_ambuja type: <class 'pandas.core.frame.DataFrame'>
# df_ambuja shape: (4716, 5)
#               open    high     low   close    volume
# Date
# 2024-02-20  585.00  590.00  579.70  588.80   70585.0
# 2024-02-19  586.65  593.80  581.70  584.80  204358.0
# 2024-02-16  572.50  590.45  572.50  585.25  197780.0
# 2024-02-15  573.65  574.80  568.75  571.80   46967.0
# 2024-02-14  560.85  573.10  559.70  570.85  101565.0

# %% [markdown]
# During each trading day, the price of a stock will change, so when we're looking at whether a stock might be a good investment, we look at four types of numbers: open, high, low, close, volume. **Open** is exactly what it sounds like: the selling price of a share when the market opens for the day. Similarly, **close** is the selling price of a share when the market closes at the end of the day, and **high** and **low** are the respective maximum and minimum prices of a share over the course of the day. **Volume** is the number of shares of a given stock that have been bought and sold that day. Generally speaking, a firm whose shares have seen a high volume of trading will see more price variation of the course of the day than a firm whose shares have been more lightly traded.
#
# Let's visualize how the price of Ambuja Cement changes over the last decade.

# %% [markdown]
# ##### Data Analysis

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# Define Suzlon ticker symbol
ticker = "AMBUJACEM.BSE"

# Use your `av` object to get daily data
df_ambuja = av.get_daily(ticker=ticker)

print("df_ambuja type:", type(df_ambuja))
print("df_ambuja shape:", df_ambuja.shape)
df_ambuja.head()
# Out:
# df_ambuja type: <class 'pandas.core.frame.DataFrame'>
# df_ambuja shape: (4716, 5)
#               open    high     low   close    volume
# Date
# 2024-02-20  585.00  590.00  579.70  588.80   70585.0
# 2024-02-19  586.65  593.80  581.70  584.80  204358.0
# 2024-02-16  572.50  590.45  572.50  585.25  197780.0
# 2024-02-15  573.65  574.80  568.75  571.80   46967.0
# 2024-02-14  560.85  573.10  559.70  570.85  101565.0

# %%
fig, ax = plt.subplots(figsize=(15, 6))
# Plot `df_ambuja` closing price
df_ambuja['close'].plot(ax=ax, label = "AMBUJACEM", color="orange")
df_suzlon["close"].plot(ax=ax, label = "SUZLON")

# Label axes
plt.xlabel("Date")
plt.ylabel("Closing Price")


# Add legend
plt.legend()

# %%
# Reset index to make 'Date' a regular column
df_ambuja_reset = df_ambuja.reset_index()
df_suzlon_reset = df_suzlon.reset_index()

# Plot using Plotly Express
fig = px.line(df_ambuja_reset, x='Date', y='close', labels={'close': 'AMBUJACEM'}, line_shape='linear')
fig.add_scatter(x=df_suzlon_reset['Date'], y=df_suzlon_reset['close'], mode='lines', name='SUZLON', line=dict(color='orange'))

# Set title and axis labelsc
fig.update_layout(
    title='Closing Price Comparison',
    xaxis_title='Date',
    yaxis_title='Closing Price',
    title_x=0.5
)

# Show the figure
fig.show()

# %%
fig, ax = plt.subplots(figsize=(15, 6))
# Plot `df_ambuja` closing price
df_ambuja['close'].plot(ax=ax, label = "AMBUJACEM", color="orange")

# Label axes
plt.xlabel("Date")
plt.ylabel("Closing Price")


# Add legend
plt.legend()

# %%
# Reset index to make 'Date' a regular column
df_ambuja_reset = df_ambuja.reset_index()
df_suzlon_reset = df_suzlon.reset_index()

# Plot using Plotly Express
fig = px.line(df_ambuja_reset, x='Date', y='close', labels={'close': 'AMBUJACEM'}, line_shape='linear')

# Set title and axis labels
fig.update_layout(
    title='Closing Price for Ambuja Cement',
    xaxis_title='Date',
    yaxis_title='Closing Price',
    title_x=0.5
)

# Show the figure
fig.show()

# %%
fig, ax = plt.subplots(figsize=(15, 6))
# Plot `df_ambuja` closing price
df_suzlon["close"].plot(ax=ax, label = "SUZLON")

# Label axes
plt.xlabel("Date")
plt.ylabel("Closing Price")


# Add legend
plt.legend()

# %% [markdown]
# Looking at this plot, we might conclude that Ambuja Cement is a "better" stock than Suzlon energy because its price is higher. But price is just one factor that an investor must consider when creating an investment strategy. What is definitely true is that it's hard to do a head-to-head comparison of these two stocks because there's such a large price difference.
#
# One way in which investors compare stocks is by looking at their **returns** instead. A return is the change in value in an investment, represented as a percentage. So let's look at the daily returns for our two stocks.

# %% [markdown]
# Add a `"return"` column to `df_ambuja` that shows the percentage change in the `"close"` column from one day to the next.

# %%
# Sort DataFrame ascending by date
df_ambuja.sort_index(ascending=True, inplace=True)

# Create "return" column
df_ambuja['return'] = round((df_ambuja['close'].pct_change() * 100), 2)

print("df_ambuja shape:", df_ambuja.shape)
print(df_ambuja.info())
df_ambuja.head()
# Out:
# df_ambuja shape: (4716, 6)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4716 entries, 2005-01-03 to 2024-02-20
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    4716 non-null   float64
#  1   high    4716 non-null   float64
#  2   low     4716 non-null   float64
#  3   close   4716 non-null   float64
#  4   volume  4716 non-null   float64
#  5   return  4715 non-null   float64
# dtypes: float64(6)
# memory usage: 257.9 KB
# None
#                 open      high       low     close     volume  return
# Date
# 2005-01-03  405.0001  409.5001  403.1001  407.6001  1061050.0     NaN
# 2005-01-04  410.0001  429.0001  409.0001  425.8501  2501549.0    4.48
# 2005-01-05  427.0001  439.9001  406.1501  425.9501  3537669.0    0.02
# 2005-01-06  426.0001  431.0001  412.0001  416.0501  3103853.0   -2.32
# 2005-01-07  420.0001  428.5001  418.0001  426.3001  2330736.0    2.46

# %%
# Sort DataFrame ascending by date
df_suzlon.sort_index(ascending=True, inplace=True)

# Create "return" column
df_suzlon['return'] = round((df_suzlon['close'].pct_change() * 100), 2)


print("df_suzlon shape:", df_suzlon.shape)
print(df_suzlon.info())
df_suzlon.head()
# Out:
# df_suzlon shape: (2500, 6)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2500 entries, 2013-12-31 to 2024-02-20
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    2500 non-null   float64
#  1   high    2500 non-null   float64
#  2   low     2500 non-null   float64
#  3   close   2500 non-null   float64
#  4   volume  2500 non-null   float64
#  5   return  2499 non-null   float64
# dtypes: float64(6)
# memory usage: 136.7 KB
# None
#              open   high    low  close     volume  return
# Date
# 2013-12-31  10.55  10.60  10.26  10.32   900636.0     NaN
# 2014-01-01  10.33  11.35  10.33  11.35  3005218.0    9.98
# 2014-01-02  11.35  11.60  10.40  10.54  5092247.0   -7.14
# 2014-01-03  10.70  10.95  10.46  10.86  2112111.0    3.04
# 2014-01-06  10.80  11.19  10.75  10.98  2026855.0    1.10

# %% [markdown]
# Now let's plot the returns for our two companies and see how the two compare.

# %%
fig, ax = plt.subplots(figsize=(15, 6))
# Plot returns for `df_suzlon` and `df_ambuja`
df_suzlon["return"].plot(ax=ax, label = "SUZLON", color="orange")
df_ambuja["return"].plot(ax=ax, label = "AMBUJA", color="blue")
# Label axes
plt.xlabel("Date")
plt.ylabel("Daily Returns")



# Add legend
plt.legend()
plt.show()

# %%
import plotly.express as px

# Assuming `df_suzlon` and `df_ambuja` are your DataFrames
fig = px.line(df_suzlon, x=df_suzlon.index, y='return', labels={'return': 'SUZLON'}, line_shape='linear', title='Daily Returns Comparison')
fig.add_scatter(x=df_ambuja.index, y=df_ambuja['return'], mode='lines', name='AMBUJA', line=dict(color='orange'))

# Add labels to axes
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Daily Returns'
                )
fig.update_layout(width=1000,
                height=400)

# Show the figure
fig.show()

# %%
import plotly.express as px

# Assuming `df_suzlon` and `df_ambuja` are your DataFrames
fig = px.line(df_suzlon, x=df_suzlon.index, y='return', labels={'return': 'SUZLON'}, line_shape='linear', title='Daily Returns Comparison')
fig.add_scatter(x=df_ambuja.index, y=df_ambuja['return'], mode='lines', name='AMBUJA', line=dict(color='orange'))

# Add labels to axes
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Daily Returns')

# Show the figure
fig.show()

# %% [markdown]
# Success! By representing returns as a percentage, we're able to compare two stocks that have very different prices. But what is this visualization telling us? We can see that the returns for Suzlon have a wider spread. We see big gains and big losses. In contrast, the spread for Ambuja is narrower, meaning that the price doesn't fluctuate as much.
#
# Another name for this day-to-day fluctuation in returns is called [**volatility**](https://en.wikipedia.org/wiki/Volatility_(finance)), which is another important factor for investors.
